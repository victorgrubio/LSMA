# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import norm
from scipy import stats
import matplotlib.pyplot as plt

# %%
spotify_data = pd.read_csv('Spotify_Features.csv')
spotify_data.head()
# Out:
#    speechiness   key       ...                         artist           title
# 0       0.1400   4.0       ...              Justin Timberlake  Rock Your Body
# 1       0.0555  10.0       ...                 Jennifer Lopez        I'm Glad
# 2       0.2160   3.0       ...                            B2K      Girlfriend
# 3       0.3010   1.0       ...                          Jay-Z  Excuse Me Miss
# 4       0.2440   5.0       ...        Ginuwine featuring Baby       Hell Yeah
#
# [5 rows x 19 columns]

# %%
# Plot all columns with NaN values in order to perform cleaning
df1 = spotify_data[spotify_data.isnull().any(axis=1)]
df1
# Out:
#       speechiness                   ...                                                       title
# 95            NaN                   ...                                                    Fearless
# 98            NaN                   ...                                                Fast Forward
# 106           NaN                   ...                                                    AM to PM
# 114           NaN                   ...                                              Me, Myself & I
# 131           NaN                   ...                                               Baby It's You
# 220           NaN                   ...                                                    Our Song
# 226           NaN                   ...                                     I Knew You Were Trouble
# 296           NaN                   ...                                                          22
# 352           NaN                   ...                                                  I Care 4 U
# 361           NaN                   ...                                                 Blank Space
# 393           NaN                   ...                                      Everything Has Changed
# 399           NaN                   ...                                                   I Believe
# 432           NaN                   ...                                      Get Yourself Back Home
# 437           NaN                   ...                                                        Ours
# 461           NaN                   ...                                          Be in Love Tonight
# 480           NaN                   ...                                      Teardrops on My Guitar
# 512           NaN                   ...                     We Are Never Ever Getting Back Together
# 549         0.387                   ...                                                     Imma Be
# 562           NaN                   ...                                           03 Bonnie & Clyde
# 633           NaN                   ...                                                   Sugarhigh
# 731           NaN                   ...                                                       Style
# 795           NaN                   ...                                          Poisoned with Love
# 856           NaN                   ...                                          You Belong with Me
# 868           NaN                   ...                                             Leave (Get Out)
# 949           NaN                   ...                                            Out of the Woods
# 958           NaN                   ...                                        Thinking for a While
# 968           NaN                   ...                                                   Bad Blood
# 1001          NaN                   ...                                                        Mine
# 1005          NaN                   ...                                                This or That
# 1083          NaN                   ...                          Shut the Front Door (Got My Girls)
# 1142          NaN                   ...                                                  Love Story
# 1173          NaN                   ...                                              Wildest Dreams
# 1225          NaN                   ...                                                    Let U Go
#
# [33 rows x 19 columns]

# %%
no_nan_df = spotify_data.drop([549])

# %%
#Clean all values with more than 6 NaN as they are useless
spotify_data = spotify_data.dropna(thresh=6,how='any',axis=0)
# Show the remaining missing values
nan_row = spotify_data[spotify_data.isnull().any(axis=1)]

# %%
# Get missing value using KNN
# Train KNN learner
from sklearn.neighbors import KNeighborsRegressor
clf = KNeighborsRegressor(5, weights='distance')

trained_model = clf.fit(no_nan_df[no_nan_df.columns.difference(['time_signature', 'artist', 'title','spotify_id'])],
                        no_nan_df.loc[:, no_nan_df.columns == 'time_signature'])
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-6-85ebd4e91ef9>", line 7, in <module>
#     no_nan_df.loc[:, no_nan_df.columns == 'time_signature'])
#
#   File "/home/victor/.virtualenvs/deeplearning/lib/python3.6/site-packages/sklearn/neighbors/base.py", line 850, in fit
#     X, y = check_X_y(X, y, "csr", multi_output=True)
#
#   File "/home/victor/.virtualenvs/deeplearning/lib/python3.6/site-packages/sklearn/utils/validation.py", line 747, in check_X_y
#     estimator=estimator)
#
#   File "/home/victor/.virtualenvs/deeplearning/lib/python3.6/site-packages/sklearn/utils/validation.py", line 568, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#
#   File "/home/victor/.virtualenvs/deeplearning/lib/python3.6/site-packages/sklearn/utils/validation.py", line 56, in _assert_all_finite
#     raise ValueError(msg_err.format(type_err, X.dtype))
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# Predict missing value and setting it to the missing value
predicted_values = trained_model.predict(nan_row[nan_row.co
# Out:
# 4.0

# %%
# Plot Histogram
var_analysis = 'danceability'
sns.distplot(spotify_data[var_analysis], fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(spotify_data[var_analysis])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('{} distribution'.format(var_analysis))

fig = plt.figure()
res = stats.probplot(spotify_data[var_analysis], plot=plt)
plt.show()

print("Skewness: %f" % spotify_data[var_analysis].skew())
print("Kurtosis: %f" % spotify_data[var_analysis].kurt())
# Out:
#  mu = 0.64 and sigma = 0.13
# Skewness: -0.180716
# Kurtosis: -0.159190

# %%
# Correlation Matrix Heatmap
corrmat = spotify_data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# Top k Heatmap
k = 3 #number of variables for heatmap
cols = corrmat.nlargest(k, var_analysis)[var_analysis].index
cm = np.corrcoef(spotify_data[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
most_corr = pd.DataFrame(cols)
most_corr.columns = ['Most Correlated Features']
most_corr
# Out:
#   Most Correlated Features
# 0             danceability
# 1                  valence
# 2              speechiness

# %%
# Comparison
var_compare = 'valence'
spotify_data[[var_analysis,var_compare]].boxplot()
